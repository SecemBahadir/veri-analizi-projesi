# %%
with open("pi_digits.txt") as dosya_objesi:
    pi_dizisi = dosya_objesi.read()                               #dosyayı okuması için bir objeye aktarılması gerekir.
    print(pi_dizisi)
# Out:
# 3.1415926535
#   8979323846
#   2643383279

# %%
with open("pi_digits.txt") as dosya_objesi:
    pi_dizisi = dosya_objesi.read()
    print(pi_dizisi.lstrip())                        #boşlukları siler
# Out:
# 3.1415926535
#   8979323846
#   2643383279

# %%
#yukarıdakiler okuyacağı dosya aynı klasörde ise çalışır.
#burda cop path diyerek dosyanın konumunu söylüyoruz bilgisayara
with open("C:/Users/Casper/Desktop/Python/dosyalar/pi_digits.txt") as dosya_objesi:
    pi_dizisi = dosya_objesi.read()                               #dosyayı okuması için bir objeye aktarılması gerekir.
    print(pi_dizisi)
    #windowsta / iaşretleri olmalı yani tersi olmalı ordaki hepsini / a dönüştür tek tek
    #C:\Users\Casper\Desktop\Python\dosyalar\pi_digits.txt olursa çalışmaz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 #yukarıdakiler okuyacağı dosya aynı klasörde ise çalışır.
#       2 #burda cop path diyerek dosyanın konumunu söylüyoruz bilgisayara
# ----> 3 with "C:/Users/Casper/Desktop/Python/dosyalar/pi_digits.txt" as dosya_objesi:
#       4     pi_dizisi = dosya_objesi.read()                               #dosyayı okuması için bir objeye aktarılması gerekir.
#       5     print(pi_dizisi)
#
# TypeError: 'str' object does not support the context manager protocol

# %%
with open("../dosyalar/pi_digits.txt") as dosya_objesi:
    pi_dizisi = dosya_objesi.read()
    print(pi_dizisi)
#burdada relative path ile söylüyoruz ikisinini avantajı ve dezavantajı var.    
#bende 2 side ayrı klasörde olduğu için normalde dosyalar/pi_digits.txt olan path e .. ekledim
#bu iki üste çık demek çünkü ipynb dosyasının bulunduğu hizadad değil ikisde ayrı bir klasörde o yüzden bulamıyor
#bu path ipynb dosyasına göre istediğim/yazdığım dosya nerde demek
# Out:
# 3.1415926535
#   8979323846
#   2643383279

# %%
dosya_yolu = "../dosyalar/pi_digits.txt"
with open(dosya_yolu) as dosya_objesi:
    for satir in dosya_objesi:
        print(satir)
# Out:
# 3.1415926535
#
#   8979323846
#
#   2643383279

# %%
with open(dosya_yolu) as dosya_objesi:
    satirlar=dosya_objesi.readlines()
print(satirlar)
print("\n")

for satir in satirlar:
    print(satir.rstrip())
# Out:
# ['3.1415926535\n', '  8979323846\n', '  2643383279']
#
#
# 3.1415926535
#   8979323846
#   2643383279

# %%
with open(dosya_yolu) as dosya_objesi:
    satirlar=dosya_objesi.readlines()

    pi_metni=""
    for satir in satirlar:
        pi_metni += satir.strip()
    print(pi_metni)

dogum_gunu= input("Doğum gününüzü girin(ggaayy):")
if dogum_gunu in pi_metni:
    print("Doğum gününüzpi sayısında bulunuyor ! ")
else:
    print("Doğum gününüz pi sayısında yok.")
# Out:
# 3.141592653589793238462643383279
# Doğum gününüz pi sayısında yok.
