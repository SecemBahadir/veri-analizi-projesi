# %%
print("merhaba python")
# Out:
# merhaba python

# %%
mesaj = """Bu örnekten sonra dersin bitmesini isteyenler el kaldırsın.
Ama önce örneği herkesin yapması lazım. """

# %%
print(mesaj)
# Out:
# Bu örnekten sonra dersin bitmesini isteyenler el kaldırsın.
# Ama önce örneği herkesin yapması lazım.

# %%
mesaj = "Uzun bir metin mesajı olabilir bu şekilde ifade edilebilir." 
print(mesaj)
# Out:
# Uzun bir metin mesajı olabilir bu şekilde ifade edilebilir.

# %%
print(mesaj)
# Out:
# Uzun bir metin mesajı olabilir bu şekilde ifade edilebilir.

# %%
mesaj = 'bu mesajın "bu kısmı" önemli' 
print(mesaj)
# Out:
# bu mesajın "bu kısmı" önemli

# %%
mesaj = """bu mesajın "bu kısmı" önemli"""
print(mesaj)

print(mesaj.upper())
# Out:
# bu mesajın "bu kısmı" önemli
# BU MESAJIN "BU KISMI" ÖNEMLI

# %%
mesaj = mesaj.upper()
print(mesaj)
print(mesaj.lower())
print(mesaj.title())
# Out:
# BU MESAJIN "BU KISMI" ÖNEMLI
# bu mesajin "bu kismi" önemli
# Bu Mesajin "Bu Kismi" Önemli

# %%
isim = "secem" 
soyisim = "bahadır" 

print(f"{isim}.title() {soyisim}.title()")
print(f"{isim.title()} {soyisim.title()}") 
print(isim.title() + " " + soyisim.title() + " için python dünyası açılıyor")

print(isim + " " + soyisim)
# Out:
# secem.title() bahadır.title()
# Secem Bahadır
# Secem Bahadır için python dünyası açılıyor
# secem bahadır

# %%
print("123" "456")
print(123 + 456)
# Out:
# 123456
# 579

# %%
print(f"{123} + {456} = 123 + 456") 
print(f"{123 + 456} = 123 + 456")
# Out:
# 123 + 456 = 123 + 456
# 579 = 123 + 456

# %%
print("\tMerhaba, \nDünya!")
# Out:
# 	Merhaba,
# Dünya!

# %%
mesaj = "a  Boşluk  b" 
print(mesaj)
# Out:
# a  Boşluk  b

# %%
print(mesaj.strip())
# Out:
# a  Boşluk  b

# %%
mesaj = "\tBoşluk     " 
print(mesaj)
# Out:
# 	Boşluk

# %%
print(mesaj.lstrip())
# Out:
# Boşluk

# %%
print(mesaj.rstrip())
# Out:
# 	Boşluk

# %%
print("""
---------------
-             -
---------------
""")
# Out:
# ---------------
# -             -
# ---------------

# %%
print(3 + 5 * 2 - 8 / 4)
# Out:
# 11.0

# %%
a = 10
b = 3
print(a + b)
# Out:
# 13

# %%
print(a ** b)
# Out:
# 1000

# %%
a = 10.5
b = 3.2
print(a ** b)
# Out:
# 1852.7027964066515

# %%
a = 10.5
b = 3.2 
print(int(a ** b))
# Out:
# 1852

# %%
a = 10.5
b = 3.2
print(int(a) ** int(b))
# Out:
# 1000

# %%
a = input("bir sayı giriniz:")
b = input("bir sayı giriniz:")
print(a + b)
# Out:
# 10.5

# %%
a = float(input("bir sayı giriniz:"))
b = float(input("bir sayı giriniz:"))
print(a + b)
# Out:
# 13.7
