# %%
şehirler = ["İstanbul", "Ankara", "İzmir", "Bursa", "Antalya"]
print(şehirler)
# Out:
# ['İstanbul', 'Ankara', 'İzmir', 'Bursa', 'Antalya']

# %%
print(şehirler[0])
# Out:
# İstanbul

# %%
print(şehirler[0:3:2])
# Out:
# ['İstanbul', 'İzmir']

# %%
şehirler = ["İstanbul" , "Ankara" , "İzmir" , "Bursa", "Antalya" , "İzmit" , "Adana", 
"Zonguldak" , "Karabük" , "Gaziantep" , "Şanlıurfa" , "Aydın" ]

# %%
print(şehirler[3::2])
# Out:
# ['Bursa', 'İzmit', 'Zonguldak', 'Gaziantep', 'Aydın']

# %%
print(şehirler[2:8:1])
# Out:
# ['İzmir', 'Bursa', 'Antalya', 'İzmit', 'Adana', 'Zonguldak']

# %%
print(şehirler[9:5:-2])
# Out:
# ['Gaziantep', 'Zonguldak']

# %%
type(şehirler)
# Out:
# list

# %%
print(şehirler[3].upper())
# Out:
# BURSA

# %%
notlar = [90, 80, 70, 60, 50]
type(notlar[2])
# Out:
# int

# %%
deger = [ "Secem" , 25 , 1.68 , "Dogru" ] 
type(deger[1])
# Out:
# int

# %%
type(deger[3])
# Out:
# str

# %%
notlar = [90, 80, 70, 60, 50] , [ "Ali" , "Veli" , "Ayşe" , "Fatma" , "Canan" ]

# %%
print(notlar[1][3] )
# Out:
# Fatma

# %%
print(notlar[-1][-2])
# Out:
# Fatma

# %%
print(f"{notlar[1][3]} isimli öğrencinin notu {notlar[0][3]}")
# Out:
# Fatma isimli öğrencinin notu 60

# %%
notlar[0].append(85)
notlar[1].append("Deniz")

# %%
print(notlar)
# Out:
# ([90, 80, 70, 60, 50, 85], ['Ali', 'Veli', 'Ayşe', 'Fatma', 'Canan', 'Deniz'])

# %%
notlar[0].remove(50)
notlar[1].remove("Canan")

# %%
del notlar[0][0]
del notlar[1][0]

# %%
notlar[0].insert(0,95)
notlar[1].insert(0,"Ahmet")

# %%
print(notlar)
# Out:
# ([95, 80, 70, 60, 85], ['Ahmet', 'Veli', 'Ayşe', 'Fatma', 'Deniz'])

# %%
notlar[0].pop()
notlar[1].pop()
print(notlar)
# Out:
# ([95, 80, 70], ['Ahmet', 'Veli', 'Ayşe'])
