# %%
import dersödev
dersödev.ders_ekle("Matematik", "MAT101", 4)
# Out:
# Matematik (MAT101) dersi eklendi. Kredi: 4
# 1. hafta: Matematik dersi işlendi.
# 2. hafta: Matematik dersi işlendi.
# 3. hafta: Matematik dersi işlendi.

# %%
import dersödev
dersödev.ders_sil("Matematik")
# Out:
# Matematik dersi silindi.
