# %%
def main():
    # [KURAL 3] Liste kullanımı (Geçmiş işlemleri saklamak için)
    gecmis = []

    print("--- Basit Hesap Makinesi ---")
    print("Çıkmak için 'q', Geçmişi görmek için 'h' yazın.")

    # [KURAL 1] While Döngüsü (Program sürekli çalışsın diye)
    while True:
        # [KURAL 5] String değişken alma
        giris = input("\nBirinci sayıyı girin (veya q/h): ")

        # [KURAL 4] Metot kullanımı: .lower() (Küçük harfe çevirir)
        if giris.lower() == 'q':
            print("Program kapatılıyor...")
            break
        
        elif giris.lower() == 'h':
            print("\n--- İŞLEM GEÇMİŞİ ---")
            # Listeyi yazdırmak için for döngüsü
            if len(gecmis) == 0:
                print("Henüz işlem yapılmadı.")
            else:
                for islem in gecmis:
                    print(islem)
            continue # Başa dön

        # [KURAL 2] If-Elif-Else Koşullu Yapı (İşlem seçimi)
        try:
            sayi1 = float(giris)
            operator = input("İşlem (+, -, *, /): ")
            sayi2 = float(input("İkinci sayıyı girin: "))
            
            sonuc = 0
            if operator == '+':
                sonuc = sayi1 + sayi2
            elif operator == '-':
                sonuc = sayi1 - sayi2
            elif operator == '*':
                sonuc = sayi1 * sayi2
            elif operator == '/':
                if sayi2 == 0:
                    print("Hata: Bir sayı 0'a bölünemez!")
                continue # Döngü başına dön
                sonuc = sayi1 / sayi2

            else:
                print("Hatalı işlem seçtiniz!")
                continue

            # Sonucu ekrana yaz
            print(f"SONUÇ: {sonuc}")

            # [KURAL 4] Metot kullanımı: .append() (Listeye ekleme)
            # Yapılan işlemi listeye kaydediyoruz
            kayit = f"{sayi1} {operator} {sayi2} = {sonuc}"
            gecmis.append(kayit)

        except ValueError:
            print("Lütfen geçerli bir sayı girin!")

# Programı çalıştır
if __name__ == "__main__":
    main()
# Out:
# --- Basit Hesap Makinesi ---
# Çıkmak için 'q', Geçmişi görmek için 'h' yazın.
# Hata: Bir sayı 0'a bölünemez!
# Program kapatılıyor...
